# %%
from scripts.utils.utils_plotting_and_post_processing import *
import pandas as pd

# %%
df_new_implementation = pd.read_csv("/Users/reyesfer/Desktop/qDriftExtraPolation/scripts/parameter_sweep/qft_qpe_qdrift/qdrift_qpe_stats_2025-07-17.csv")
df_new_implementation
# Out:
#         ham  n_sys  Num Ancilla      Time  segments  replication_seed  \
# 0     ising      2            8  0.001055         1                 1
# 1     ising      2            8  0.000977         1                 1
# 2     ising      2            8  0.001055         1                 3
# 3     ising      2            8  0.001055         1                 2
# 4     ising      2            8  0.001055         1                 0
# ...     ...    ...          ...       ...       ...               ...
# 1195  ising      2           12  1.851749         1                 3
# 1196  ising      2           12  2.000000         1                 1
# 1197  ising      2           12  2.000000         1                 0
# 1198  ising      2           12  2.000000         1                 2
# 1199  ising      2           12  2.000000         1                 3
#
#       n_circuits  n_shots  depth  size     peak_MB  exact_eig  most_likely_bs  \
# ...

# %%
plot_error_vs_time(df_new_implementation, "qDRIFT-QPE: new implementation", true_eigenval=1.2806248474865685)

# %%
new_new_implementation = pd.read_csv("/Users/reyesfer/Desktop/qDriftExtraPolation/scripts/parameter_sweep/qft_qpe_qdrift/qdrift_qpe_stats_2025-07-20.csv")
plot_error_vs_time(new_new_implementation, "qDRIFT-QPE: new implementation (2025-07-20)", true_eigenval=1.2806248474865685)
